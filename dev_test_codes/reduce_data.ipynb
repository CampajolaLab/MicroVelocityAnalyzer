# %%
import pandas as pd
import numpy as np

# %%
alloc = pd.read_csv("data/stablecoins/USDT_allocation.csv")

transfers = pd.read_csv("data/stablecoins/USDT_transfer.csv")

# %%
alloc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4897 entries, 0 to 4896
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   to_address    4897 non-null   int64
#  1   amount        4897 non-null   int64
#  2   block_number  4897 non-null   int64
# dtypes: int64(3)
# memory usage: 114.9 KB

# %%
transfers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227684082 entries, 0 to 227684081
# Data columns (total 4 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   from_address  int64
#  1   to_address    int64
#  2   amount        int64
#  3   block_number  int64
# dtypes: int64(4)
# memory usage: 6.8 GB

# %%
MAX_BLOCK = 10000000

# %%
alloc_red = alloc.loc[alloc['block_number'] < MAX_BLOCK]

# %%
transfers_red = transfers.loc[transfers['block_number'] < MAX_BLOCK]

# %%
alloc_red.to_csv("data/stablecoins/USDT_allocation_test.csv", index=False)
transfers_red.to_csv("data/stablecoins/USDT_transfer_test.csv", index=False)

# %%
transfers_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27760948 entries, 0 to 27760947
# Data columns (total 4 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   from_address  int64
#  1   to_address    int64
#  2   amount        int64
#  3   block_number  int64
# dtypes: int64(4)
# memory usage: 1.0 GB
